# %%
import pickle
import pandas as pd
import os

# %%
dataset = None

with open('dataset.bin', 'rb') as f:
    dataset = pickle.load(f)

# %%
len(dataset)
# Out:
# 2994444

# %%
dataset[154000:156000]
# Out:
# ['얘는 해부 인형 제인이라고 해',
#  '그건 크리의 물건이다',
#  '내 아내 벨라야 안녕하세요',
#  '일본이 얘기하는 화기관제레이더는 국방부가 언급한 추적레이더를 가리킨다',
#  '최적의 온도보다 2도 가량 낮다는 분석이 나왔다',
#  '그러나 현행 소화기 표지는 눈에 잘 띄지 않아 평소 관심이 없으면 소화기 위치를 알기 어렵고 갑작스러운 화재 발생 시 소화기를 찾느라 골든타임을 놓칠 수 있다',
#  '높은 기온으로 모기 개체 수가 줄어들긴 했지만 여름 휴가지로 많이 찾는 동남아 지역은 여전히 모기 매개 감염병 발생이 일어나고 있어 주의가 필요하다',
#  '자기 초음파 방향 탐지 기능이 고장 났다는데 의사 말로는 이상 없대',
#  '경찰은 해당 문건 가운데 정치관여나 불법사찰 등 불법성이 의심되는 60건과 대통령에게 보고되지는 않았지만 문제가 있다고 판단된 70건 등 총 30건에 대해 검찰에 수사를 의뢰했다',
#  '무서워 죽을 거 같아 내가 아빠가 돼서가 아니라',
#  '시와 시에서 출자출연하는 기관에서 위탁 운영하는 컨택센터 기업의 경우에는 지원을 제외한다',
#  '끝났다고',
#  '이에 소방당국은 관할 소방서의 인력과 장비가 총동원되는 대응 단계를 발령하고 펌프차 2대와 출동 가능한 진화인력을 총동원해 불을 끄고 있다',
#  '이에 경기도에서는 경제적으로 취약한 저소득층 어린이에게 치료비 지원 및 가족상담 집단프로그램등과 같은 체계적인 사후관리 서비스를 제공함으로서 경제적 어려움으로 치료가 단절되는 사례가 발생되지 않도록 최선의 노력을 다할 방침이다',
#  '서울청 광역수사대는 2일 서울 강남경찰서 소속 경찰관이 버닝썬 측에 현금을 받은 정황을 포착해 수사 중이라고 밝혔다',
#  '대전시가 지난달말 마무리한 차 실태파악 결과에 따르면 원도심 중앙로프로젝트 사업 구역 내에 모두 480개의 빈 점포가 발생했다',
# ...
